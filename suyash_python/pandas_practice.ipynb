# %% [markdown]
# 1. Import numpy and pandas libraries in the notebook
# 2. load automobile.csv file in the notebook
# 3. Do a basic inspection and print the first and last 15 rows of your dataframe
# 4. You need to clean the data a little bit now. Replace all column values with the values ? and n.a with NaN
# 5. Print the company name which manufactured the most expensive car. Also print the price of the most expensive car
# 6. Calculate Maximum Horsepower for Each Company
# 7. Print the total number of cars manufactured by each company
# 8. Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled
# 9.

# %%
import numpy as np
import pandas as pd

# %%
cars = pd.read_csv("Automobile_data.csv")
cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
cars.isnull().sum() # To check whether the dataset has null values or not
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
cars.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
cars.shape
# Out:
# (205, 26)

# %%
cars.head(15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
cars.tail(15)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 190          3               256  volkswagen       gas        std
# 191          0                 ?  volkswagen       gas        std
# 192          0                 ?  volkswagen    diesel      turbo
# 193          0                 ?  volkswagen       gas        std
# 194         -2               103       volvo       gas        std
# 195         -1                74       volvo       gas        std
# 196         -2               103       volvo       gas        std
# 197         -1                74       volvo       gas        std
# 198         -2               103       volvo       gas      turbo
# 199         -1                74       volvo       gas      turbo
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# ...

# %%
list_of = list(cars.columns)
for i in list_of:
  cars[i] = cars[i].replace('?',np.nan)
  print(cars[i])
# Out:
# 0      3
# 1      3
# 2      1
# 3      2
# 4      2
#       ..
# 200   -1
# 201   -1
# 202   -1
# 203   -1
# 204   -1
# Name: symboling, Length: 205, dtype: int64
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 200       gas
# 201       gas
# 202       gas
# 203    diesel
# 204       gas
# Name: fuel-type, Length: 205, dtype: object
# 0        std
# 1        std
# 2        std
# 3        std
# 4        std
#        ...
# 200      std
# 201    turbo
# 202      std
# 203    turbo
# ...

# %%
cars['price'] = pd.to_numeric(cars['price'], errors='coerce')

# %%
cars['price'].max()
# Out:
# 45400.0

# %%
cars.groupby(['make'])['horsepower'].max().reset_index()
# Out:
#              make horsepower
# 0     alfa-romero        154
# 1            audi        160
# 2             bmw        182
# 3       chevrolet         70
# 4           dodge         88
# 5           honda         86
# 6           isuzu         90
# 7          jaguar        262
# 8           mazda         84
# 9   mercedes-benz        184
# 10        mercury        175
# 11     mitsubishi         88
# 12         nissan         97
# 13         peugot         97
# 14       plymouth         88
# 15        porsche        288
# 16        renault        NaN
# 17           saab        160
# 18         subaru         94
# 19         toyota         92
# 20     volkswagen         90
# 21          volvo        162

# %%
cars.groupby(['make'])['make'].count()
# Out:
# make
# alfa-romero       3
# audi              7
# bmw               8
# chevrolet         3
# dodge             9
# honda            13
# isuzu             4
# jaguar            3
# mazda            17
# mercedes-benz     8
# mercury           1
# mitsubishi       13
# nissan           18
# peugot           11
# plymouth          7
# porsche           5
# renault           2
# saab              6
# subaru           12
# toyota           32
# volkswagen       12
# volvo            11
# Name: make, dtype: int64

# %%
def UPD(engine, price):
    if engine=='rear': updated_price = price * 2
    else: updated_price = price
    return updated_price

# %%
cars['updated_price'] = cars.apply(lambda x: UPD_PRC(x['engine-location'],x['price']),axis=1)
cars
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
cars.sort_values(['make','price'],ascending = [True,True]).head(15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 4           2               164         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               NaN         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
int_doors = 0
def INT_DOORS(doors):
    if doors == 'two':int_doors =+ 2
    elif doors == 'four':int_doors =+ 4
    else: return None
    return int_doors

# %%
cars['int-doors'] = cars.apply(lambda x: INT_DOORS(x['num-of-doors']),axis = 1)
cars.head(15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               NaN         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
cars1 = pd.DataFrame({'Company':['Ford','Mercedes','BMW','Audi'],'Price':[30000,450000,134560,75000]}, index=[0,1,2,3])
cars2 = pd.DataFrame({'Company':['Maruti Suzuki','Honda','Toyota','Tata'],'Price':[400000,450000,600000,750000]}, index=[4,5,6,7])
pd.concat([cars1,cars2])
# Out:
#          Company   Price
# 0           Ford   30000
# 1       Mercedes  450000
# 2            BMW  134560
# 3           Audi   75000
# 4  Maruti Suzuki  400000
# 5          Honda  450000
# 6         Toyota  600000
# 7           Tata  750000

# %%
pd.concat([cars1,cars2],axis = 1)
# Out:
#     Company     Price        Company     Price
# 0      Ford   30000.0            NaN       NaN
# 1  Mercedes  450000.0            NaN       NaN
# 2       BMW  134560.0            NaN       NaN
# 3      Audi   75000.0            NaN       NaN
# 4       NaN       NaN  Maruti Suzuki  400000.0
# 5       NaN       NaN          Honda  450000.0
# 6       NaN       NaN         Toyota  600000.0
# 7       NaN       NaN           Tata  750000.0
